# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("karachi_house_prices.csv")

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#                                                Address       Price  \
# 0                         Bahria Town Karachi, Karachi     42 Lakh
# 1       Bahria Town - Precinct 17, Bahria Town Karachi     59 Lakh
# 2                 Bahria Paradise, Bahria Town Karachi   4.2 Crore
# 3                        Askari 5 - Sector J, Askari 5  3.75 Crore
# 4        Bahria Town - Precinct 35, Bahria Sports City   2.1 Crore
# ...                                                ...         ...
# 19445  Gulshan-e-Iqbal - Block 13/D-1, Gulshan-e-Iqbal     49 Lakh
# 19446           Emaar Pearl Towers, Emaar Crescent Bay  6.75 Crore
# 19447                          Federal B Area, Karachi     45 Lakh
# 19448    Gulshan-e-Iqbal - Block 13/C, Gulshan-e-Iqbal   2.5 Crore
# 19449   Gwalior Cooperative Housing Society, Scheme 33     80 Lakh
#
#       NoOfBedrooms NoOfBathrooms  AreaSqYards  \
# 0                1             1   60 Sq. Yd.
# 1                2             2  161 Sq. Yd.
# 2                5             5  500 Sq. Yd.
# 3                3             3  300 Sq. Yd.
# 4                4             4  350 Sq. Yd.
# ...            ...           ...          ...
# 19445            2             2   67 Sq. Yd.
# 19446            3             4  243 Sq. Yd.
# 19447            2             1   67 Sq. Yd.
# 19448            4             4  240 Sq. Yd.
# 19449            2             2  106 Sq. Yd.
#
#                                                 WebURL
# 0        https://www.zameen.com/Homes/Karachi-2-1.html
# 1        https://www.zameen.com/Homes/Karachi-2-1.html
# 2        https://www.zameen.com/Homes/Karachi-2-1.html
# 3        https://www.zameen.com/Homes/Karachi-2-1.html
# 4        https://www.zameen.com/Homes/Karachi-2-1.html
# ...                                                ...
# 19445  https://www.zameen.com/Homes/Karachi-2-778.html
# 19446  https://www.zameen.com/Homes/Karachi-2-778.html
# 19447  https://www.zameen.com/Homes/Karachi-2-778.html
# 19448  https://www.zameen.com/Homes/Karachi-2-778.html
# 19449  https://www.zameen.com/Homes/Karachi-2-778.html
#
# [19450 rows x 6 columns]

# %%
# convert column to numeric data type, replacing invalid values with NaN
arr = pd.to_numeric(df["NoOfBathrooms"], errors="coerce")

# %%
df["NoOfBathrooms"] = arr

# %%
df["NoOfBedrooms"] = pd.to_numeric(df["NoOfBedrooms"], errors="coerce")

# %%
df.sample(15)
# Out:
#                                                  Address       Price  \
# 18736                       Gulshan-e-Maymar, Gadap Town   1.1 Crore
# 3063                       Askari 5 - Sector G, Askari 5  8.25 Crore
# 872                     Saima Arabian Villas, Gadap Town  1.49 Crore
# 7850                        Bahria Town Karachi, Karachi  27.84 Lakh
# 11999                Bahria Heights, Bahria Town Karachi   1.2 Crore
# 8108                       Askari 5 - Sector J, Askari 5  6.85 Crore
# 8197                            DHA Phase 8, DHA Defence  23.8 Crore
# 15956                         Gulistan-e-Jauhar, Karachi  5.25 Crore
# 2            5.0  500 Sq. Yd.  https://www.zameen.com/Homes/Karachi-2-1.html
# 3            3.0  300 Sq. Yd.  https://www.zameen.com/Homes/Karachi-2-1.html
# 4            4.0  350 Sq. Yd.  https://www.zameen.com/Homes/Karachi-2-1.html

# %%
import re

df["AreaSqYards"] = df["AreaSqYards"].str.extract(r'(\d+(?:\.\d+)?)').astype(int)

# %%
df.head()
# Out:
#                                           Address       Price  NoOfBedrooms  \
# 0                    Bahria Town Karachi, Karachi     42 Lakh           1.0
# 1  Bahria Town - Precinct 17, Bahria Town Karachi     59 Lakh           2.0
# 2            Bahria Paradise, Bahria Town Karachi   4.2 Crore           5.0
# 3                   Askari 5 - Sector J, Askari 5  3.75 Crore           3.0
# 4   Bahria Town - Precinct 35, Bahria Sports City   2.1 Crore           4.0
#
#    NoOfBathrooms  AreaSqYards                                         WebURL
# 0            1.0           60  https://www.zameen.com/Homes/Karachi-2-1.html
# 1            2.0          161  https://www.zameen.com/Homes/Karachi-2-1.html
# 2            5.0          500  https://www.zameen.com/Homes/Karachi-2-1.html
# 3            3.0          300  https://www.zameen.com/Homes/Karachi-2-1.html
# 4            4.0          350  https://www.zameen.com/Homes/Karachi-2-1.html

# %%
df["Price"].unique
# Out:
# <bound method Series.unique of 0           42 Lakh
# 1           59 Lakh
# 2         4.2 Crore
# 3        3.75 Crore
# 4         2.1 Crore
#             ...
# 19445       49 Lakh
# 19446    6.75 Crore
# 19447       45 Lakh
# 19448     2.5 Crore
# 19449       80 Lakh
# Name: Price, Length: 19450, dtype: object>

# %%
# extract numeric value using regular expressions
def func(x):
    return float(re.findall("\d+\.*\d*", x)[0])

df.loc[df['Price'].astype(str).str.contains('Lakh'), 'Price'] = df.loc[df['Price'].astype(str).str.contains('Lakh'), 'Price'].apply(func) * 10**5
df.loc[df['Price'].astype(str).str.contains('Crore'), 'Price'] = df.loc[df['Price'].astype(str).str.contains('Crore'), 'Price'].apply(func) * 10**7

# %%
df.head()
# Out:
#                                           Address       Price  NoOfBedrooms  \
# 0                    Bahria Town Karachi, Karachi   4200000.0           1.0
# 1  Bahria Town - Precinct 17, Bahria Town Karachi   5900000.0           2.0
# 2            Bahria Paradise, Bahria Town Karachi  42000000.0           5.0
# 3                   Askari 5 - Sector J, Askari 5  37500000.0           3.0
# 4   Bahria Town - Precinct 35, Bahria Sports City  21000000.0           4.0
#
#    NoOfBathrooms  AreaSqYards                                         WebURL
# 0            1.0           60  https://www.zameen.com/Homes/Karachi-2-1.html
# 1            2.0          161  https://www.zameen.com/Homes/Karachi-2-1.html
# 2            5.0          500  https://www.zameen.com/Homes/Karachi-2-1.html
# 3            3.0          300  https://www.zameen.com/Homes/Karachi-2-1.html
# 4            4.0          350  https://www.zameen.com/Homes/Karachi-2-1.html

# %%
df.to_csv("Karachi_House_Price_Dataset.csv")
